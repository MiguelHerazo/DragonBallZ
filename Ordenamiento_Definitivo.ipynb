# %% [markdown]
# <a href="https://colab.research.google.com/github/MiguelHerazo/DragonBallZ/blob/master/Ordenamiento_Definitivo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import json
import requests
from pandas import json_normalize

# %%
ruta = " https://www.datos.gov.co/resource/u37r-hjmu.json"
datos = requests.get(ruta)
datos = json.loads(datos.text)
datos = json_normalize(datos)
orden = datos["mod_comuni_escrita_punt"]
orden.array
# Out:
# <PandasArray>
# ['174', '170',  '77', '157', '132', '127', '165', '157', '116', '136',
#  ...
#  '107', '101', '186', '136', '155', '136', '127', '140', '138', '145']
# Length: 1000, dtype: object

# %% [markdown]
# QUICK

# %%
def quick(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    return quick(left) + middle + quick(right)

# Obtener los datos de la URL
ruta = "https://www.datos.gov.co/resource/u37r-hjmu.json"
respuesta = requests.get(ruta)
datos = json.loads(respuesta.text)

# Convertir los datos JSON en un DataFrame de pandas
df = pd.DataFrame(datos)

# Eliminar filas con valores NaN en la columna 'mod_comuni_escrita_punt'
df = df.dropna(subset=['mod_comuni_escrita_punt'])

# Convertir la columna 'mod_comuni_escrita_punt' a números enteros, omitiendo los valores no numéricos
df['mod_comuni_escrita_punt'] = pd.to_numeric(df['mod_comuni_escrita_punt'], errors='coerce')

# Eliminar filas con valores no numéricos en la columna 'mod_comuni_escrita_punt'
df = df.dropna(subset=['mod_comuni_escrita_punt'])

# Obtener los datos ordenados utilizando Quicksort
datos_ordenados = quick(df['mod_comuni_escrita_punt'].tolist())

# Mostrar los datos ordenados
print(datos_ordenados)
# Out:
# [0, 0, 0, 0, 0, 0, 65, 74, 75, 75, 77, 83, 84, 85, 87, 88, 88, 89, 89, 89, 89, 91, 91, 93, 94, 95, 96, 96, 96, 96, 96, 96, 97, 97, 97, 97, 98, 98, 98, 98, 99, 101, 101, 101, 101, 102, 102, 102, 102, 103, 103, 103, 103, 103, 103, 103, 103, 104, 104, 104, 104, 104, 105, 105, 105, 105, 105, 105, 106, 106, 106, 107, 107, 107, 107, 107, 108, 108, 108, 108, 108, 108, 108, 108, 108, 109, 109, 110, 110, 110, 110, 111, 111, 112, 112, 112, 112, 112, 113, 113, 113, 113, 114, 114, 114, 114, 114, 115, 116, 116, 116, 116, 116, 117, 117, 117, 117, 118, 118, 118, 118, 118, 119, 119, 119, 120, 120, 120, 120, 120, 120, 121, 121, 121, 121, 121, 122, 122, 122, 122, 122, 122, 122, 122, 123, 123, 123, 123, 123, 123, 123, 123, 123, 123, 123, 123, 124, 124, 124, 124, 124, 124, 124, 124, 125, 125, 126, 126, 126, 126, 126, 126, 126, 126, 126, 126, 126, 126, 127, 127, 127, 127, 127, 127, 127, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 129, 129, 129, 129, 129, 129, 129, 129,
# ...

# %% [markdown]
# COUNTING

# %%
def countingsort(arr):
    if len(arr) == 0:
        return arr

    # Encontrar el rango de los elementos
    min_val = min(arr)
    max_val = max(arr)
    range_val = max_val - min_val + 1

    # Inicializar el arreglo de conteo y el arreglo de salida
    count = [0] * range_val
    output = [0] * len(arr)

    # Contar la frecuencia de cada elemento
    for num in arr:
        count[num - min_val] += 1

    # Calcular las posiciones finales de cada elemento
    for i in range(1, range_val):
        count[i] += count[i - 1]

    # Colocar los elementos en el arreglo de salida
    for i in range(len(arr) - 1, -1, -1):
        output[count[arr[i] - min_val] - 1] = arr[i]
        count[arr[i] - min_val] -= 1

    return output

# Obtener los datos de la URL
ruta = "https://www.datos.gov.co/resource/u37r-hjmu.json"
respuesta = requests.get(ruta)
datos = json.loads(respuesta.text)

# Convertir los datos JSON en un DataFrame de pandas
df = pd.DataFrame(datos)

# Eliminar filas con valores NaN en la columna 'mod_comuni_escrita_punt'
df = df.dropna(subset=['mod_comuni_escrita_punt'])

# Convertir la columna 'mod_comuni_escrita_punt' a números enteros, omitiendo los valores no numéricos
df['mod_comuni_escrita_punt'] = pd.to_numeric(df['mod_comuni_escrita_punt'], errors='coerce')

# Eliminar filas con valores no numéricos en la columna 'mod_comuni_escrita_punt'
df = df.dropna(subset=['mod_comuni_escrita_punt'])

# Obtener los datos ordenados utilizando Counting Sort
datos_ordenados = countingsort(df['mod_comuni_escrita_punt'].astype(int).tolist())

# Mostrar los datos ordenados
print(datos_ordenados)
# Out:
# [0, 0, 0, 0, 0, 0, 65, 74, 75, 75, 77, 83, 84, 85, 87, 88, 88, 89, 89, 89, 89, 91, 91, 93, 94, 95, 96, 96, 96, 96, 96, 96, 97, 97, 97, 97, 98, 98, 98, 98, 99, 101, 101, 101, 101, 102, 102, 102, 102, 103, 103, 103, 103, 103, 103, 103, 103, 104, 104, 104, 104, 104, 105, 105, 105, 105, 105, 105, 106, 106, 106, 107, 107, 107, 107, 107, 108, 108, 108, 108, 108, 108, 108, 108, 108, 109, 109, 110, 110, 110, 110, 111, 111, 112, 112, 112, 112, 112, 113, 113, 113, 113, 114, 114, 114, 114, 114, 115, 116, 116, 116, 116, 116, 117, 117, 117, 117, 118, 118, 118, 118, 118, 119, 119, 119, 120, 120, 120, 120, 120, 120, 121, 121, 121, 121, 121, 122, 122, 122, 122, 122, 122, 122, 122, 123, 123, 123, 123, 123, 123, 123, 123, 123, 123, 123, 123, 124, 124, 124, 124, 124, 124, 124, 124, 125, 125, 126, 126, 126, 126, 126, 126, 126, 126, 126, 126, 126, 126, 127, 127, 127, 127, 127, 127, 127, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 129, 129, 129, 129, 129, 129, 129, 129,
# ...

# %% [markdown]
# Bucket

# %%
import requests
import json
import pandas as pd

def bucket_sort(arr):
    # Número de buckets
    num_buckets = 10

    # Crear buckets vacíos
    buckets = [[] for _ in range(num_buckets)]

    # Distribuir los elementos en los buckets
    for num in arr:
        index = min(num // 10, num_buckets - 1)  # Calcular el índice del bucket
        buckets[index].append(num)

    # Ordenar cada bucket
    for i in range(num_buckets):
        buckets[i].sort()

    # Combinar los buckets ordenados
    sorted_arr = []
    for bucket in buckets:
        sorted_arr.extend(bucket)

    return sorted_arr

# Obtener los datos de la URL
ruta = "https://www.datos.gov.co/resource/u37r-hjmu.json"
respuesta = requests.get(ruta)
datos = json.loads(respuesta.text)

# Convertir los datos JSON en un DataFrame de pandas
df = pd.DataFrame(datos)

# Eliminar filas con valores NaN en la columna 'mod_comuni_escrita_punt'
df = df.dropna(subset=['mod_comuni_escrita_punt'])

# Convertir la columna 'mod_comuni_escrita_punt' a números enteros, omitiendo los valores no numéricos
df['mod_comuni_escrita_punt'] = pd.to_numeric(df['mod_comuni_escrita_punt'], errors='coerce')

# Eliminar filas con valores no numéricos en la columna 'mod_comuni_escrita_punt'
df = df.dropna(subset=['mod_comuni_escrita_punt'])

# Obtener los datos ordenados utilizando Bucket Sort
datos_ordenados = bucket_sort(df['mod_comuni_escrita_punt'].astype(int).tolist())

# Mostrar los datos ordenados
print(datos_ordenados)
# Out:
# [0, 0, 0, 0, 0, 0, 65, 74, 75, 75, 77, 83, 84, 85, 87, 88, 88, 89, 89, 89, 89, 91, 91, 93, 94, 95, 96, 96, 96, 96, 96, 96, 97, 97, 97, 97, 98, 98, 98, 98, 99, 101, 101, 101, 101, 102, 102, 102, 102, 103, 103, 103, 103, 103, 103, 103, 103, 104, 104, 104, 104, 104, 105, 105, 105, 105, 105, 105, 106, 106, 106, 107, 107, 107, 107, 107, 108, 108, 108, 108, 108, 108, 108, 108, 108, 109, 109, 110, 110, 110, 110, 111, 111, 112, 112, 112, 112, 112, 113, 113, 113, 113, 114, 114, 114, 114, 114, 115, 116, 116, 116, 116, 116, 117, 117, 117, 117, 118, 118, 118, 118, 118, 119, 119, 119, 120, 120, 120, 120, 120, 120, 121, 121, 121, 121, 121, 122, 122, 122, 122, 122, 122, 122, 122, 123, 123, 123, 123, 123, 123, 123, 123, 123, 123, 123, 123, 124, 124, 124, 124, 124, 124, 124, 124, 125, 125, 126, 126, 126, 126, 126, 126, 126, 126, 126, 126, 126, 126, 127, 127, 127, 127, 127, 127, 127, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 129, 129, 129, 129, 129, 129, 129, 129,
# ...

# %% [markdown]
# MERGE PAI

# %%
import requests
import json
import pandas as pd

def merge_sort(arr):
    if len(arr) <= 1:
        return arr

    # Dividir el arreglo en dos mitades
    mid = len(arr) // 2
    left = arr[:mid]
    right = arr[mid:]

    # Aplicar merge_sort recursivamente a ambas mitades
    left = merge_sort(left)
    right = merge_sort(right)

    # Combinar ambas mitades ordenadas
    return merge(left, right)

def merge(left, right):
    result = []
    i = j = 0

    # Combinar los elementos de ambas mitades en orden
    while i < len(left) and j < len(right):
        if left[i] <= right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1

    # Agregar los elementos restantes de la mitad izquierda
    result.extend(left[i:])

    # Agregar los elementos restantes de la mitad derecha
    result.extend(right[j:])

    return result

# Obtener los datos de la URL
ruta = "https://www.datos.gov.co/resource/u37r-hjmu.json"
respuesta = requests.get(ruta)
datos = json.loads(respuesta.text)

# Convertir los datos JSON en un DataFrame de pandas
df = pd.DataFrame(datos)

# Eliminar filas con valores NaN en la columna 'mod_comuni_escrita_punt'
df = df.dropna(subset=['mod_comuni_escrita_punt'])

# Convertir la columna 'mod_comuni_escrita_punt' a números enteros, omitiendo los valores no numéricos
df['mod_comuni_escrita_punt'] = pd.to_numeric(df['mod_comuni_escrita_punt'], errors='coerce')

# Eliminar filas con valores no numéricos en la columna 'mod_comuni_escrita_punt'
df = df.dropna(subset=['mod_comuni_escrita_punt'])

# Obtener los datos ordenados utilizando Merge Sort
datos_ordenados = merge_sort(df['mod_comuni_escrita_punt'].astype(int).tolist())

# Mostrar los datos ordenados
print(datos_ordenados)
# Out:
# [0, 0, 0, 0, 0, 0, 65, 74, 75, 75, 77, 83, 84, 85, 87, 88, 88, 89, 89, 89, 89, 91, 91, 93, 94, 95, 96, 96, 96, 96, 96, 96, 97, 97, 97, 97, 98, 98, 98, 98, 99, 101, 101, 101, 101, 102, 102, 102, 102, 103, 103, 103, 103, 103, 103, 103, 103, 104, 104, 104, 104, 104, 105, 105, 105, 105, 105, 105, 106, 106, 106, 107, 107, 107, 107, 107, 108, 108, 108, 108, 108, 108, 108, 108, 108, 109, 109, 110, 110, 110, 110, 111, 111, 112, 112, 112, 112, 112, 113, 113, 113, 113, 114, 114, 114, 114, 114, 115, 116, 116, 116, 116, 116, 117, 117, 117, 117, 118, 118, 118, 118, 118, 119, 119, 119, 120, 120, 120, 120, 120, 120, 121, 121, 121, 121, 121, 122, 122, 122, 122, 122, 122, 122, 122, 123, 123, 123, 123, 123, 123, 123, 123, 123, 123, 123, 123, 124, 124, 124, 124, 124, 124, 124, 124, 125, 125, 126, 126, 126, 126, 126, 126, 126, 126, 126, 126, 126, 126, 127, 127, 127, 127, 127, 127, 127, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 129, 129, 129, 129, 129, 129, 129, 129,
# ...
